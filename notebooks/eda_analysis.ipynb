# %% [markdown]
# # AutoML Algorithm Recommendation System
# ## EDA Analysis Notebook
# This notebook runs the EDA pipeline and visualizes the meta-dataset.

# %%
import sys
sys.path.append('../src')

from EDA import DataProcessor

processor = DataProcessor(
    input_path='../data/raw/meta_dataset.csv',
    output_path='../data/processed/clean_meta_dataset.csv'
)
processor.load_data()

# %%
processor.data_quality_check()

# %%
processor.clean_data()

# %%
processor.outlier_inspection()

# %%
processor.generate_visualizations()

# %%
processor.save_cleaned_data()
print('Cleaned dataset saved.')
